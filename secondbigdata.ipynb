# %%
import numpy as np
import pandas as pd

# %%
df_yield = pd.read_csv('/content/Untitled Folder/pesticides.csv')
df_yield = pd.read_csv('/content/Untitled Folder/rainfall.csv')
df_yield = pd.read_csv('/content/Untitled Folder/temp.csv')
df_yield = pd.read_csv('/content/Untitled Folder/yield.csv')
df_yield = pd.read_csv('/content/Untitled Folder/yield_df.csv')
df_yield.shape
# Out:
# (28242, 8)

# %%
df_yield.head()
# Out:
#    Unnamed: 0     Area         Item  Year  hg/ha_yield  \
# 0           0  Albania        Maize  1990        36613
# 1           1  Albania     Potatoes  1990        66667
# 2           2  Albania  Rice, paddy  1990        23333
# 3           3  Albania      Sorghum  1990        12500
# 4           4  Albania     Soybeans  1990         7000
#
#    average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                         1485.0              121.0     16.37
# 1                         1485.0              121.0     16.37
# 2                         1485.0              121.0     16.37
# 3                         1485.0              121.0     16.37
# 4                         1485.0              121.0     16.37

# %%
df_yield.tail(10)
# Out:
#        Unnamed: 0      Area            Item  Year  hg/ha_yield  \
# 28232       28232  Zimbabwe  Sweet potatoes  2012        22222
# 28233       28233  Zimbabwe           Wheat  2012        24420
# 28234       28234  Zimbabwe         Cassava  2013        46000
# 28235       28235  Zimbabwe           Maize  2013         7449
# 28236       28236  Zimbabwe        Potatoes  2013       165714
# 28237       28237  Zimbabwe     Rice, paddy  2013        22581
# 28238       28238  Zimbabwe         Sorghum  2013         3066
# 28239       28239  Zimbabwe        Soybeans  2013        13142
# 28240       28240  Zimbabwe  Sweet potatoes  2013        22222
# 28241       28241  Zimbabwe           Wheat  2013        22888
#
#        average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 28232                          657.0            3375.53     20.52
# 28233                          657.0            3375.53     20.52
# 28234                          657.0            2550.07     19.76
# 28235                          657.0            2550.07     19.76
# 28236                          657.0            2550.07     19.76
# 28237                          657.0            2550.07     19.76
# 28238                          657.0            2550.07     19.76
# 28239                          657.0            2550.07     19.76
# 28240                          657.0            2550.07     19.76
# 28241                          657.0            2550.07     19.76

# %%
# rename columns.
df_yield = df_yield.rename(index=str, columns={"Value": "hg/ha_yield"})
df_yield.head()
# Out:
#    Unnamed: 0     Area         Item  Year  hg/ha_yield  \
# 0           0  Albania        Maize  1990        36613
# 1           1  Albania     Potatoes  1990        66667
# 2           2  Albania  Rice, paddy  1990        23333
# 3           3  Albania      Sorghum  1990        12500
# 4           4  Albania     Soybeans  1990         7000
#
#    average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                         1485.0              121.0     16.37
# 1                         1485.0              121.0     16.37
# 2                         1485.0              121.0     16.37
# 3                         1485.0              121.0     16.37
# 4                         1485.0              121.0     16.37

# %%
df_yield.describe()
# Out:
#          Unnamed: 0          Year    hg/ha_yield  \
# count  28242.000000  28242.000000   28242.000000
# mean   14120.500000   2001.544296   77053.332094
# std     8152.907488      7.051905   84956.612897
# min        0.000000   1990.000000      50.000000
# 25%     7060.250000   1995.000000   19919.250000
# 50%    14120.500000   2001.000000   38295.000000
# 75%    21180.750000   2008.000000  104676.750000
# max    28241.000000   2013.000000  501412.000000
#
#        average_rain_fall_mm_per_year  pesticides_tonnes      avg_temp
# count                    28242.00000       28242.000000  28242.000000
# mean                      1149.05598       37076.909344     20.542627
# std                        709.81215       59958.784665      6.312051
# min                         51.00000           0.040000      1.300000
# 25%                        593.00000        1702.000000     16.702500
# 50%                       1083.00000       17529.440000     21.510000
# 75%                       1668.00000       48687.880000     26.000000
# max                       3240.00000      367778.000000     30.650000

# %%
df_yield.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28242 entries, 0 to 28241
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     28242 non-null  int64
#  1   Area                           28242 non-null  object
#  2   Item                           28242 non-null  object
#  3   Year                           28242 non-null  int64
#  4   hg/ha_yield                    28242 non-null  int64
#  5   average_rain_fall_mm_per_year  28242 non-null  float64
#  6   pesticides_tonnes              28242 non-null  float64
#  7   avg_temp                       28242 non-null  float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 2.9+ MB

# %%
df_rain = pd.read_csv('/content/rainfall.csv')
df_rain.head()
# Out:
#           Area  Year average_rain_fall_mm_per_year
# 0  Afghanistan  1985                           327
# 1  Afghanistan  1986                           327
# 2  Afghanistan  1987                           327
# 3  Afghanistan  1989                           327
# 4  Afghanistan  1990                           327

# %%
df_rain.tail()
# Out:
#           Area  Year average_rain_fall_mm_per_year
# 6722  Zimbabwe  2013                           657
# 6723  Zimbabwe  2014                           657
# 6724  Zimbabwe  2015                           657
# 6725  Zimbabwe  2016                           657
# 6726  Zimbabwe  2017                           657

# %%
df_rain = df_rain.rename(index=str, columns={" Area": 'Area'})

# %%
df_rain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6727 entries, 0 to 6726
# Data columns (total 3 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Area                           6727 non-null   object
#  1   Year                           6727 non-null   int64
#  2   average_rain_fall_mm_per_year  5953 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 210.2+ KB

# %%
df_rain['average_rain_fall_mm_per_year'] = pd.to_numeric(df_rain['average_rain_fall_mm_per_year'],errors = 'coerce')
df_rain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6727 entries, 0 to 6726
# Data columns (total 3 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Area                           6727 non-null   object
#  1   Year                           6727 non-null   int64
#  2   average_rain_fall_mm_per_year  5947 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 210.2+ KB

# %%
df_rain = df_rain.dropna()

# %%
df_rain.describe()
# Out:
#               Year  average_rain_fall_mm_per_year
# count  5947.000000                    5947.000000
# mean   2001.365899                    1124.743232
# std       9.526335                     786.257365
# min    1985.000000                      51.000000
# 25%    1993.000000                     534.000000
# 50%    2001.000000                    1010.000000
# 75%    2010.000000                    1651.000000
# max    2017.000000                    3240.000000

# %%
yield_df = pd.merge(df_yield, df_rain, on=['Year','Area'])

# %%
yield_df.head()
# Out:
#    Unnamed: 0     Area         Item  Year  hg/ha_yield  \
# 0           0  Albania        Maize  1990        36613
# 1           1  Albania     Potatoes  1990        66667
# 2           2  Albania  Rice, paddy  1990        23333
# 3           3  Albania      Sorghum  1990        12500
# 4           4  Albania     Soybeans  1990         7000
#
#    average_rain_fall_mm_per_year_x  pesticides_tonnes  avg_temp  \
# 0                           1485.0              121.0     16.37
# 1                           1485.0              121.0     16.37
# 2                           1485.0              121.0     16.37
# 3                           1485.0              121.0     16.37
# 4                           1485.0              121.0     16.37
#
#    average_rain_fall_mm_per_year_y
# 0                           1485.0
# 1                           1485.0
# 2                           1485.0
# 3                           1485.0
# 4                           1485.0

# %%
yield_df.describe()
# Out:
#          Unnamed: 0          Year    hg/ha_yield  \
# count  28242.000000  28242.000000   28242.000000
# mean   14120.500000   2001.544296   77053.332094
# std     8152.907488      7.051905   84956.612897
# min        0.000000   1990.000000      50.000000
# 25%     7060.250000   1995.000000   19919.250000
# 50%    14120.500000   2001.000000   38295.000000
# 75%    21180.750000   2008.000000  104676.750000
# max    28241.000000   2013.000000  501412.000000
#
#        average_rain_fall_mm_per_year_x  pesticides_tonnes      avg_temp  \
# count                      28242.00000       28242.000000  28242.000000
# mean                        1149.05598       37076.909344     20.542627
# std                          709.81215       59958.784665      6.312051
# min                           51.00000           0.040000      1.300000
# 25%                          593.00000        1702.000000     16.702500
# 50%                         1083.00000       17529.440000     21.510000
# 75%                         1668.00000       48687.880000     26.000000
# max                         3240.00000      367778.000000     30.650000
#
#        average_rain_fall_mm_per_year_y
# count                      28242.00000
# mean                        1149.05598
# std                          709.81215
# min                           51.00000
# 25%                          593.00000
# 50%                         1083.00000
# 75%                         1668.00000
# max                         3240.00000

# %%
df_pes = pd.read_csv('/content/pesticides.csv')
df_pes.head()
# Out:
#            Domain     Area Element                Item  Year  \
# 0  Pesticides Use  Albania     Use  Pesticides (total)  1990
# 1  Pesticides Use  Albania     Use  Pesticides (total)  1991
# 2  Pesticides Use  Albania     Use  Pesticides (total)  1992
# 3  Pesticides Use  Albania     Use  Pesticides (total)  1993
# 4  Pesticides Use  Albania     Use  Pesticides (total)  1994
#
#                            Unit  Value
# 0  tonnes of active ingredients  121.0
# 1  tonnes of active ingredients  121.0
# 2  tonnes of active ingredients  121.0
# 3  tonnes of active ingredients  121.0
# 4  tonnes of active ingredients  201.0

# %%
df_pes = df_pes.rename(index=str, columns={"Value": "pesticides_tonnes"})
df_pes = df_pes.drop(['Element','Domain','Unit','Item'], axis=1)
df_pes.head()
# Out:
#       Area  Year  pesticides_tonnes
# 0  Albania  1990              121.0
# 1  Albania  1991              121.0
# 2  Albania  1992              121.0
# 3  Albania  1993              121.0
# 4  Albania  1994              201.0

# %%
df_pes.describe()
# Out:
#               Year  pesticides_tonnes
# count  4349.000000       4.349000e+03
# mean   2003.138883       2.030334e+04
# std       7.728044       1.177362e+05
# min    1990.000000       0.000000e+00
# 25%    1996.000000       9.300000e+01
# 50%    2003.000000       1.137560e+03
# 75%    2010.000000       7.869000e+03
# max    2016.000000       1.807000e+06

# %%
df_pes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4349 entries, 0 to 4348
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Area               4349 non-null   object
#  1   Year               4349 non-null   int64
#  2   pesticides_tonnes  4349 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 264.9+ KB

# %%
yield_df = pd.merge(yield_df, df_pes, on=['Year','Area'])
yield_df.shape
# Out:
# (28242, 10)

# %%
yield_df.head()
# Out:
#    Unnamed: 0     Area         Item  Year  hg/ha_yield  \
# 0           0  Albania        Maize  1990        36613
# 1           1  Albania     Potatoes  1990        66667
# 2           2  Albania  Rice, paddy  1990        23333
# 3           3  Albania      Sorghum  1990        12500
# 4           4  Albania     Soybeans  1990         7000
#
#    average_rain_fall_mm_per_year_x  pesticides_tonnes_x  avg_temp  \
# 0                           1485.0                121.0     16.37
# 1                           1485.0                121.0     16.37
# 2                           1485.0                121.0     16.37
# 3                           1485.0                121.0     16.37
# 4                           1485.0                121.0     16.37
#
#    average_rain_fall_mm_per_year_y  pesticides_tonnes_y
# 0                           1485.0                121.0
# 1                           1485.0                121.0
# 2                           1485.0                121.0
# 3                           1485.0                121.0
# 4                           1485.0                121.0

# %%
avg_temp=  pd.read_csv('/content/temp.csv')

# %%
avg_temp.head()
# Out:
#    year        country  avg_temp
# 0  1849  Côte D'Ivoire     25.58
# 1  1850  Côte D'Ivoire     25.52
# 2  1851  Côte D'Ivoire     25.67
# 3  1852  Côte D'Ivoire       NaN
# 4  1853  Côte D'Ivoire       NaN

# %%
avg_temp.describe()
# Out:
#                year      avg_temp
# count  71311.000000  68764.000000
# mean    1905.799007     16.183876
# std       67.102099      7.592960
# min     1743.000000    -14.350000
# 25%     1858.000000      9.750000
# 50%     1910.000000     16.140000
# 75%     1962.000000     23.762500
# max     2013.000000     30.730000

# %%
avg_temp = avg_temp.rename(index=str, columns={"year": "Year", "country":'Area'})
avg_temp.head()
# Out:
#    Year           Area  avg_temp
# 0  1849  Côte D'Ivoire     25.58
# 1  1850  Côte D'Ivoire     25.52
# 2  1851  Côte D'Ivoire     25.67
# 3  1852  Côte D'Ivoire       NaN
# 4  1853  Côte D'Ivoire       NaN

# %%
yield_df = pd.merge(yield_df,avg_temp, on=['Area','Year'])
yield_df.head()
# Out:
#    Unnamed: 0     Area         Item  Year  hg/ha_yield  \
# 0           0  Albania        Maize  1990        36613
# 1           1  Albania     Potatoes  1990        66667
# 2           2  Albania  Rice, paddy  1990        23333
# 3           3  Albania      Sorghum  1990        12500
# 4           4  Albania     Soybeans  1990         7000
#
#    average_rain_fall_mm_per_year_x  pesticides_tonnes_x  avg_temp_x  \
# 0                           1485.0                121.0       16.37
# 1                           1485.0                121.0       16.37
# 2                           1485.0                121.0       16.37
# 3                           1485.0                121.0       16.37
# 4                           1485.0                121.0       16.37
#
#    average_rain_fall_mm_per_year_y  pesticides_tonnes_y  avg_temp_y
# 0                           1485.0                121.0       16.37
# 1                           1485.0                121.0       16.37
# 2                           1485.0                121.0       16.37
# 3                           1485.0                121.0       16.37
# 4                           1485.0                121.0       16.37

# %%
yield_df.shape
# Out:
# (186094, 11)

# %%
yield_df.describe()
# Out:
#           Unnamed: 0           Year    hg/ha_yield  \
# count  186094.000000  186094.000000  186094.000000
# mean    12861.124357    2001.462605   80332.936425
# std      6453.392537       7.063155   89403.065039
# min         0.000000    1990.000000      50.000000
# 25%     10587.000000    1995.000000   19125.000000
# 50%     12702.000000    2001.000000   31874.000000
# 75%     15853.750000    2008.000000  113463.000000
# max     28241.000000    2013.000000  501412.000000
#
#        average_rain_fall_mm_per_year_x  pesticides_tonnes_x     avg_temp_x  \
# count                    186094.000000        186094.000000  186094.000000
# mean                       1142.587096         58963.395172      22.996121
# std                         525.943513         68504.571020       5.072132
# min                          51.000000             0.040000       1.300000
# 25%                         758.000000         27422.770000      20.310000
# 50%                        1083.000000         44957.520000      25.360000
# 75%                        1083.000000         61732.110000      26.400000
# max                        3240.000000        367778.000000      30.650000
#
#        average_rain_fall_mm_per_year_y  pesticides_tonnes_y     avg_temp_y
# count                    186094.000000        186094.000000  186094.000000
# mean                       1142.587096         58963.395172      22.996121
# std                         525.943513         68504.571020       5.072132
# min                          51.000000             0.040000       1.300000
# 25%                         758.000000         27422.770000      20.310000
# 50%                        1083.000000         44957.520000      25.360000
# 75%                        1083.000000         61732.110000      26.400000
# max                        3240.000000        367778.000000      30.650000

# %%
yield_df.isnull().sum()
# Out:
# Unnamed: 0                         0
# Area                               0
# Item                               0
# Year                               0
# hg/ha_yield                        0
# average_rain_fall_mm_per_year_x    0
# pesticides_tonnes_x                0
# avg_temp_x                         0
# average_rain_fall_mm_per_year_y    0
# pesticides_tonnes_y                0
# avg_temp_y                         0
# dtype: int64

# %%
yield_df.groupby('Item').count()
# Out:
#                       Unnamed: 0   Area   Year  hg/ha_yield  \
# Item
# Cassava                    17455  17455  17455        17455
# Maize                      24683  24683  24683        24683
# Plantains and others         786    786    786          786
# Potatoes                   25298  25298  25298        25298
# Rice, paddy                23030  23030  23030        23030
# Sorghum                    21041  21041  21041        21041
# Soybeans                   23557  23557  23557        23557
# Sweet potatoes             21938  21938  21938        21938
# Wheat                      24143  24143  24143        24143
# Yams                        4163   4163   4163         4163
#
#                       average_rain_fall_mm_per_year_x  pesticides_tonnes_x  \
# Item
# Cassava                                         17455                17455
# Maize                                           24683                24683
# Plantains and others                              786                  786
# Potatoes                                        25298                25298
# Rice, paddy                                     23030                23030
# Sorghum                                         21041                21041
# Soybeans                                        23557                23557
# Sweet potatoes                                  21938                21938
# Wheat                                           24143                24143
# Yams                                             4163                 4163
#
#                       avg_temp_x  average_rain_fall_mm_per_year_y  \
# Item
# Cassava                    17455                            17455
# Maize                      24683                            24683
# Plantains and others         786                              786
# Potatoes                   25298                            25298
# Rice, paddy                23030                            23030
# Sorghum                    21041                            21041
# Soybeans                   23557                            23557
# Sweet potatoes             21938                            21938
# Wheat                      24143                            24143
# Yams                        4163                             4163
#
#                       pesticides_tonnes_y  avg_temp_y
# Item
# Cassava                             17455       17455
# Maize                               24683       24683
# Plantains and others                  786         786
# Potatoes                            25298       25298
# Rice, paddy                         23030       23030
# Sorghum                             21041       21041
# Soybeans                            23557       23557
# Sweet potatoes                      21938       21938
# Wheat                               24143       24143
# Yams                                 4163        4163

# %%
yield_df.describe()
# Out:
#           Unnamed: 0           Year    hg/ha_yield  \
# count  186094.000000  186094.000000  186094.000000
# mean    12861.124357    2001.462605   80332.936425
# std      6453.392537       7.063155   89403.065039
# min         0.000000    1990.000000      50.000000
# 25%     10587.000000    1995.000000   19125.000000
# 50%     12702.000000    2001.000000   31874.000000
# 75%     15853.750000    2008.000000  113463.000000
# max     28241.000000    2013.000000  501412.000000
#
#        average_rain_fall_mm_per_year_x  pesticides_tonnes_x     avg_temp_x  \
# count                    186094.000000        186094.000000  186094.000000
# mean                       1142.587096         58963.395172      22.996121
# std                         525.943513         68504.571020       5.072132
# min                          51.000000             0.040000       1.300000
# 25%                         758.000000         27422.770000      20.310000
# 50%                        1083.000000         44957.520000      25.360000
# 75%                        1083.000000         61732.110000      26.400000
# max                        3240.000000        367778.000000      30.650000
#
#        average_rain_fall_mm_per_year_y  pesticides_tonnes_y     avg_temp_y
# count                    186094.000000        186094.000000  186094.000000
# mean                       1142.587096         58963.395172      22.996121
# std                         525.943513         68504.571020       5.072132
# min                          51.000000             0.040000       1.300000
# 25%                         758.000000         27422.770000      20.310000
# 50%                        1083.000000         44957.520000      25.360000
# 75%                        1083.000000         61732.110000      26.400000
# max                        3240.000000        367778.000000      30.650000

# %%
yield_df['Area'].nunique()
# Out:
# 101

# %%
yield_df.groupby(['Area'],sort=True)['hg/ha_yield'].sum().nlargest(10)
# Out:
# Area
# India             7203247128
# Brazil            1843053366
# Mexico            1046308224
# Japan              746825472
# Pakistan           665076906
# Australia          654666372
# Indonesia          415161036
# United Kingdom     277099950
# Turkey             261319750
# Canada             208241532
# Name: hg/ha_yield, dtype: int64

# %%
yield_df.groupby(['Item','Area'],sort=True)['hg/ha_yield'].sum().nlargest(10)
# Out:
# Item            Area
# Cassava         India       3141833728
# Potatoes        India       2026695308
# Sweet potatoes  India        977669836
# Potatoes        Brazil       545623848
# Cassava         Brazil       370383541
# Rice, paddy     India        337252168
# Potatoes        Mexico       336431040
# Sweet potatoes  Brazil       310931522
# Potatoes        Pakistan     296727786
# Wheat           India        295519268
# Name: hg/ha_yield, dtype: int64

# %%
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt

# %%
yield_df.head()
# Out:
#    Unnamed: 0     Area         Item  Year  hg/ha_yield  \
# 0           0  Albania        Maize  1990        36613
# 1           1  Albania     Potatoes  1990        66667
# 2           2  Albania  Rice, paddy  1990        23333
# 3           3  Albania      Sorghum  1990        12500
# 4           4  Albania     Soybeans  1990         7000
#
#    average_rain_fall_mm_per_year_x  pesticides_tonnes_x  avg_temp_x  \
# 0                           1485.0                121.0       16.37
# 1                           1485.0                121.0       16.37
# 2                           1485.0                121.0       16.37
# 3                           1485.0                121.0       16.37
# 4                           1485.0                121.0       16.37
#
#    average_rain_fall_mm_per_year_y  pesticides_tonnes_y  avg_temp_y
# 0                           1485.0                121.0       16.37
# 1                           1485.0                121.0       16.37
# 2                           1485.0                121.0       16.37
# 3                           1485.0                121.0       16.37
# 4                           1485.0                121.0       16.37

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
yield_df_onehot = pd.get_dummies(yield_df, columns=['Area',"Item"], prefix = ['Country',"Item"])
features=yield_df_onehot.loc[:, yield_df_onehot.columns != 'hg/ha_yield']
label=yield_df['hg/ha_yield']
features.head()
# Out:
#    Unnamed: 0  Year  average_rain_fall_mm_per_year_x  pesticides_tonnes_x  \
# 0           0  1990                           1485.0                121.0
# 1           1  1990                           1485.0                121.0
# 2           2  1990                           1485.0                121.0
# 3           3  1990                           1485.0                121.0
# 4           4  1990                           1485.0                121.0
#
#    avg_temp_x  average_rain_fall_mm_per_year_y  pesticides_tonnes_y  \
# 0       16.37                           1485.0                121.0
# 1       16.37                           1485.0                121.0
# 2       16.37                           1485.0                121.0
# 3       16.37                           1485.0                121.0
# 4       16.37                           1485.0                121.0
#
#    avg_temp_y  Country_Albania  Country_Algeria  ...  Item_Cassava  \
# 0       16.37             True            False  ...         False
# 1       16.37             True            False  ...         False
# 2       16.37             True            False  ...         False
# 3       16.37             True            False  ...         False
# 4       16.37             True            False  ...         False
#
#    Item_Maize  Item_Plantains and others  Item_Potatoes  Item_Rice, paddy  \
# 0        True                      False          False             False
# 1       False                      False           True             False
# 2       False                      False          False              True
# 3       False                      False          False             False
# 4       False                      False          False             False
#
#    Item_Sorghum  Item_Soybeans  Item_Sweet potatoes  Item_Wheat  Item_Yams
# 0         False          False                False       False      False
# 1         False          False                False       False      False
# 2         False          False                False       False      False
# 3          True          False                False       False      False
# 4         False           True                False       False      False
#
# [5 rows x 119 columns]

# %%
features = features.drop(['Year'], axis=1)

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186094 entries, 0 to 186093
# Columns: 118 entries, Unnamed: 0 to Item_Yams
# dtypes: bool(111), float64(6), int64(1)
# memory usage: 29.6 MB

# %%
features.head()
# Out:
#    Unnamed: 0  average_rain_fall_mm_per_year_x  pesticides_tonnes_x  \
# 0           0                           1485.0                121.0
# 1           1                           1485.0                121.0
# 2           2                           1485.0                121.0
# 3           3                           1485.0                121.0
# 4           4                           1485.0                121.0
#
#    avg_temp_x  average_rain_fall_mm_per_year_y  pesticides_tonnes_y  \
# 0       16.37                           1485.0                121.0
# 1       16.37                           1485.0                121.0
# 2       16.37                           1485.0                121.0
# 3       16.37                           1485.0                121.0
# 4       16.37                           1485.0                121.0
#
#    avg_temp_y  Country_Albania  Country_Algeria  Country_Angola  ...  \
# 0       16.37             True            False           False  ...
# 1       16.37             True            False           False  ...
# 2       16.37             True            False           False  ...
# 3       16.37             True            False           False  ...
# 4       16.37             True            False           False  ...
#
#    Item_Cassava  Item_Maize  Item_Plantains and others  Item_Potatoes  \
# 0         False        True                      False          False
# 1         False       False                      False           True
# 2         False       False                      False          False
# 3         False       False                      False          False
# 4         False       False                      False          False
#
#    Item_Rice, paddy  Item_Sorghum  Item_Soybeans  Item_Sweet potatoes  \
# 0             False         False          False                False
# 1             False         False          False                False
# 2              True         False          False                False
# 3             False          True          False                False
# 4             False         False           True                False
#
#    Item_Wheat  Item_Yams
# 0       False      False
# 1       False      False
# 2       False      False
# 3       False      False
# 4       False      False
#
# [5 rows x 118 columns]

# %%
from sklearn.model_selection import train_test_split
train_data, test_data, train_labels, test_labels = train_test_split(features, label, test_size=0.2, random_state=42)

# %%
yield_df_onehot = yield_df_onehot.drop(['Year'], axis=1)

# %%
yield_df_onehot.head()
# Out:
#    Unnamed: 0  hg/ha_yield  average_rain_fall_mm_per_year_x  \
# 0           0        36613                           1485.0
# 1           1        66667                           1485.0
# 2           2        23333                           1485.0
# 3           3        12500                           1485.0
# 4           4         7000                           1485.0
#
#    pesticides_tonnes_x  avg_temp_x  average_rain_fall_mm_per_year_y  \
# 0                121.0       16.37                           1485.0
# 1                121.0       16.37                           1485.0
# 2                121.0       16.37                           1485.0
# 3                121.0       16.37                           1485.0
# 4                121.0       16.37                           1485.0
#
#    pesticides_tonnes_y  avg_temp_y  Country_Albania  Country_Algeria  ...  \
# 0                121.0       16.37             True            False  ...
# 1                121.0       16.37             True            False  ...
# 2                121.0       16.37             True            False  ...
# 3                121.0       16.37             True            False  ...
# 4                121.0       16.37             True            False  ...
#
#    Item_Cassava  Item_Maize  Item_Plantains and others  Item_Potatoes  \
# 0         False        True                      False          False
# 1         False       False                      False           True
# 2         False       False                      False          False
# 3         False       False                      False          False
# 4         False       False                      False          False
#
#    Item_Rice, paddy  Item_Sorghum  Item_Soybeans  Item_Sweet potatoes  \
# 0             False         False          False                False
# 1             False         False          False                False
# 2              True         False          False                False
# 3             False          True          False                False
# 4             False         False           True                False
#
#    Item_Wheat  Item_Yams
# 0       False      False
# 1       False      False
# 2       False      False
# 3       False      False
# 4       False      False
#
# [5 rows x 119 columns]

# %%
#setting test data to columns from dataframe and excluding 'hg/ha_yield' values where ML model should be predicting

test_df=pd.DataFrame(test_data,columns=yield_df_onehot.loc[:, yield_df_onehot.columns != 'hg/ha_yield'].columns)

# using stack function to return a reshaped DataFrame by pivoting the columns of the current dataframe

cntry=test_df[[col for col in test_df.columns if 'Country' in col]].stack()[test_df[[col for col in test_df.columns if 'Country' in col]].stack()>0]
cntrylist=list(pd.DataFrame(cntry).index.get_level_values(1))
countries=[i.split("_")[1] for i in cntrylist]
itm=test_df[[col for col in test_df.columns if 'Item' in col]].stack()[test_df[[col for col in test_df.columns if 'Item' in col]].stack()>0]
itmlist=list(pd.DataFrame(itm).index.get_level_values(1))
items=[i.split("_")[1] for i in itmlist]

# %%
test_df.head()
# Out:
#         Unnamed: 0  average_rain_fall_mm_per_year_x  pesticides_tonnes_x  \
# 18850         3525                           1761.0            127585.00
# 42965         9049                            700.0             34930.37
# 122590       14045                           1083.0             55540.00
# 76383        11944                           1083.0             49157.00
# 90192        12572                           1083.0             43720.04
#
#         avg_temp_x  average_rain_fall_mm_per_year_y  pesticides_tonnes_y  \
# 18850        27.64                           1761.0            127585.00
# 42965         5.43                            700.0             34930.37
# 122590       27.29                           1083.0             55540.00
# 76383        24.34                           1083.0             49157.00
# 90192        26.02                           1083.0             43720.04
#
#         avg_temp_y  Country_Albania  Country_Algeria  Country_Angola  ...  \
# 18850        17.66            False            False           False  ...
# 42965         5.43            False            False           False  ...
# 122590       25.36            False            False           False  ...
# 76383        27.32            False            False           False  ...
# 90192        24.50            False            False           False  ...
#
#         Item_Cassava  Item_Maize  Item_Plantains and others  Item_Potatoes  \
# 18850          False       False                      False          False
# 42965          False        True                      False          False
# 122590         False        True                      False          False
# 76383          False        True                      False          False
# 90192          False       False                      False          False
#
#         Item_Rice, paddy  Item_Sorghum  Item_Soybeans  Item_Sweet potatoes  \
# 18850              False         False          False                False
# 42965              False         False          False                False
# 122590             False         False          False                False
# 76383              False         False          False                False
# 90192              False         False          False                 True
#
#         Item_Wheat  Item_Yams
# 18850        False       True
# 42965        False      False
# 122590       False      False
# 76383        False      False
# 90192        False      False
#
# [5 rows x 118 columns]

# %%
test_df['Country']=countries
test_df['Item']=items
test_df.head()
# Out:
#         Unnamed: 0  average_rain_fall_mm_per_year_x  pesticides_tonnes_x  \
# 18850         3525                           1761.0            127585.00
# 42965         9049                            700.0             34930.37
# 122590       14045                           1083.0             55540.00
# 76383        11944                           1083.0             49157.00
# 90192        12572                           1083.0             43720.04
#
#         avg_temp_x  average_rain_fall_mm_per_year_y  pesticides_tonnes_y  \
# 18850        27.64                           1761.0            127585.00
# 42965         5.43                            700.0             34930.37
# 122590       27.29                           1083.0             55540.00
# 76383        24.34                           1083.0             49157.00
# 90192        26.02                           1083.0             43720.04
#
#         avg_temp_y  Country_Albania  Country_Algeria  Country_Angola  ...  \
# 18850        17.66            False            False           False  ...
# 42965         5.43            False            False           False  ...
# 122590       25.36            False            False           False  ...
# 76383        27.32            False            False           False  ...
# 90192        24.50            False            False           False  ...
#
#         Item_Plantains and others  Item_Potatoes  Item_Rice, paddy  \
# 18850                       False          False             False
# 42965                       False          False             False
# 122590                      False          False             False
# 76383                       False          False             False
# 90192                       False          False             False
#
#         Item_Sorghum  Item_Soybeans  Item_Sweet potatoes  Item_Wheat  \
# 18850          False          False                False       False
# 42965          False          False                False       False
# 122590         False          False                False       False
# 76383          False          False                False       False
# 90192          False          False                 True       False
#
#         Item_Yams  Country            Item
# 18850        True   Brazil            Yams
# 42965       False  Germany           Maize
# 122590      False    India           Maize
# 76383       False    India           Maize
# 90192       False    India  Sweet potatoes
#
# [5 rows x 120 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
clf=DecisionTreeRegressor()
model=clf.fit(train_data,train_labels)

test_df["yield_predicted"]= model.predict(test_data)
test_df["yield_actual"]=pd.DataFrame(test_labels)["hg/ha_yield"].tolist()
test_group=test_df.groupby("Item")
# test_group.apply(lambda x: r2_score(x.yield_actual,x.yield_predicted))

# %%
# So let's run the model actual values against the predicted ones

fig, ax = plt.subplots()

ax.scatter(test_df["yield_actual"], test_df["yield_predicted"],edgecolors=(0, 0, 0))

ax.set_xlabel('Actual')
ax.set_ylabel('Predicted')
ax.set_title("Actual vs Predicted")
plt.show()
